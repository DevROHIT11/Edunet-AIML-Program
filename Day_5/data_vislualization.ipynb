# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as slt

# this function already creates dataframe so need to create data frame again
data = pd.read_csv("iris.csv")

data

# plt.hist(data["petal_length"] , width = 0.5)
# plt.xlabel("Species")
# plt.ylabel("Sepal length")
# plt.title("Species vs Sepal length")
# plt.show()
# changing the path
# os.chdir(r"C:\\Users\\Rohhit\\Documents\\Learnings\\Edunet_Program\\Day_5")

# import os
# os.getcwd()

# pair plot
slt.pairplot(data)
slt.show()

# %% [markdown]
# ### ADVANCE VISUALIZATION

# %%
# heat map

correlation_matrix = data.drop(columns="species").corr()

# plot heatmap
slt.heatmTap(correlation_matrix , annot = True , cmap = "coolwarm" , linewidth = 0.5)

# add title
plt.title("Correlation")
plt.show()

# %%
# box plot
slt.boxplot(data)

plt.title("Distribution of sepal length")
plt.show()

# %%
# violin plot

slt.violinplot(data)

plt.title("Violin plot")
plt.show()
