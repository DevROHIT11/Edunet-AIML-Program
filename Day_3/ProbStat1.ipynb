# %%
class EnergyResources:

    def __init__(self , Energy_name , solar_factor , wind_factor, hydro_factor):
        self.Energy_name = Energy_name
        self.solar_factor = solar_factor
        self.wind_factor = wind_factor
        self.hydro_factor = hydro_factor

        self._power 

    def calculate_energy(self , factor):
        self.factor = factor
        total_power = self.capacity * self.factor
        return total_power


class SolarEnergy(EnergyResources) :
    
    super().__init__(self, solar_factor)

    def __init__(self , capacity):
        self.capacity = capacity

    def calculate_energy(self , solar_factor):
        self.factor = solar_factor
        total_power = self.capacity * self.factor
        return total_power

e1 =  EnergyResources("Solar" , 0.4 , 0.6 , 0.3)

solar = SolarEnergy(500)
print(f"Solar energy = {solar.calculate_energy()}")
# class WindEnergy(EnergyResources)
# class HydroEnergy(EnergyResources)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 17
#      13         total_power = self.capacity * self.factor
#      14         return total_power
# ---> 17 class SolarEnergy(EnergyResources) :
#      19     super().__init__(self , solar_factor)
#      21     def __init__(self , capacity):
#
# Cell In[1], line 19, in SolarEnergy()
#      17 class SolarEnergy(EnergyResources) :
# ---> 19     super().__init__(self , solar_factor)
#      21     def __init__(self , capacity):
#      22         self.capacity = capacity
#
# RuntimeError: super(): no arguments
