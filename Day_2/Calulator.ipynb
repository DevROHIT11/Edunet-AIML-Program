# %%
a = float(input("Enter a Val 1: "))
b = float(input("Enter a Val 2 : "))
op = str(input("Enter operator : "))

if(op == "+"):
    print(f"The sum is : {a+b}")
elif(op == "-"):
    print(f"The substraction is : {a-b}")
elif(op == "*"):
    print(f"The multiplication is : {a*b}")
elif(op == "/"):
    print(f"The division is : {a/b}")
else:
    print("Invalid Inputs !!")
# Out:
# Enter a Val 1:  9
# Enter a Val 2 :  4
# Enter operator :  /
# The division is : 2.25
