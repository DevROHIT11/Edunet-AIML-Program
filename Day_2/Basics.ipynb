# %% [markdown]
# ### CONTROL STRUCTURES

# %%
x = 3
if(x < 10):
    print("X is lees than 10")
elif(x > 10):
    print("X is grater than 10")
# Out:
# X is lees than 10

# %%
list = [2, 3, 4, 5]
sum = 0
for i in list:
    sum += i
print(sum)
# Out:
# 14

# %% [markdown]
# ### WHILE LOOP

# %%
c = 0

while c < 10:
    print(c)
    c = c + 1

# %%
for i in range(1 , 10 ):
    if i==5:
        continue;
    print(i)
